# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans


from sklearn.metrics import silhouette_score, accuracy_score, recall_score, f1_score, precision_score, classification_report
from scipy.cluster.hierarchy import dendrogram, ward, complete, average

# %%
df=pd.read_csv('ilustrasi k means.csv',sep=';')
df
# Out:
#     tinggibadan  tinggibadanistri
# 0           175               175
# 1           178               178
# 2           175               166
# 3           180               179
# 4           185               181
# 5           178               163
# 6           175               158
# 7           181               154
# 8           168               155
# 9           171               154
# 10          177               156
# 11          158               155
# 12          158               152
# 13          175               149
# 14          172               163
# 15          158               151
# 16          153               155
# 17          150               150
# 18          157               152
# 19          154               150
# 20          157               145
# 21          160               154

# %%
df.shape
# Out:
# (22, 2)

# %% [markdown]
# ## Visualisasi

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df,x='tinggibadan',y='tinggibadanistri')

for i,text in enumerate(range(0,len(df))):
    plt.annotate(text,(df['tinggibadan'][i]+0.2,df['tinggibadanistri'][i]+0.2),fontsize=10.0)

# %% [markdown]
# ## Dendrogram

# %% [markdown]
# `Ward`

# %%
linkage_array=ward(df)

# %%
## Dendrogram Visualisation

plt.figure(figsize=(10,8))



#two culsters
plt.axhline(y=65,linestyle='--',color='red')
plt.text(10,65.5, 'Two_Cluster')


# #three culsters
plt.axhline(y=30,linestyle='--',color='blue')
plt.text(10,30.5, 'Three_Cluster')

dendrogram(linkage_array)
plt.show()

# %%
Soal 1: 
    Buat Dendrogram untuk data yang sama, tetapi dalam versi complete dan average(two clusters & three clusters)
# Out:
#   Cell In[46], line 1
#     Soal 1:
#          ^
# SyntaxError: invalid syntax
