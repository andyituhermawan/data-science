# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Binning
# `Binning` : suatu metode yang digunakan untuk mentransformasi data numerik menjadi kelompok-kelompok yang lebih kecil. Tujuannya untuk lebih mudah menganalisa kolom tersebut, selain itu bisa meningkatkan performa model(khususnya untuk model-model regresi)

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## buat histogram
sns.distplot(df['tip'],bins=5)
# Out:
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/3021599944.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],bins=5)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
bins=range(5,51,5)
for i in bins:
    print(f'bin {i}')
    sns.distplot(df['tip'],bins=i)
    plt.show()
# Out:
# bin 5
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/2559530904.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],bins=i)
# bin 10
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/2559530904.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## Binning : Equal Frequences
#
# `Equal Frequences` : Tiap kelompok memiliki count yang sama
# ### pd.qcut

# %%
df['bin_tip_eq_freq']=pd.qcut(df['tip'],5)
# df['bin_tip_eq_freq']=pd.qcut(df['tip'],5,labels=['very low','low','medium','high','very high'])
df
# Out:
#      total_bill   tip     sex smoker   day    time  size bin_tip_eq_freq  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    (0.999, 2.0]
# 1         10.34  1.66    Male     No   Sun  Dinner     3    (0.999, 2.0]
# 2         21.01  3.50    Male     No   Sun  Dinner     3    (3.016, 4.0]
# 3         23.68  3.31    Male     No   Sun  Dinner     2    (3.016, 4.0]
# 4         24.59  3.61  Female     No   Sun  Dinner     4    (3.016, 4.0]
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     (4.0, 10.0]
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    (0.999, 2.0]
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    (0.999, 2.0]
# 242       17.82  1.75    Male     No   Sat  Dinner     2    (0.999, 2.0]
# 243       18.78  3.00  Female     No  Thur  Dinner     2  (2.476, 3.016]
#
#     bin_totalbill_eq_freq bin_tip_eq_int
# 0                       4       very low
# ...

# %%
df['bin_tip_eq_freq'].value_counts()
# Out:
# bin_tip_eq_freq
# (0.999, 2.0]      78
# (3.016, 4.0]      57
# (2.476, 3.016]    48
# (4.0, 10.0]       41
# (2.0, 2.476]      20
# Name: count, dtype: int64

# %% [markdown]
# # soal 1
#
# coba lakukan binning untuk kolom total bill menggunakan pd.qcut(equal frequences), buat menjadi 8 kelompok, berikan labelnya dari 1,2,3,4,...8

# %%
df['bin_totalbill_eq_freq']=pd.qcut(df['total_bill'],8,labels=np.arange(1,9))
df
# Out:
#      total_bill   tip     sex smoker   day    time  size bin_tip_eq_freq  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    (0.999, 2.0]
# 1         10.34  1.66    Male     No   Sun  Dinner     3    (0.999, 2.0]
# 2         21.01  3.50    Male     No   Sun  Dinner     3    (3.016, 4.0]
# 3         23.68  3.31    Male     No   Sun  Dinner     2    (3.016, 4.0]
# 4         24.59  3.61  Female     No   Sun  Dinner     4    (3.016, 4.0]
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     (4.0, 10.0]
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    (0.999, 2.0]
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    (0.999, 2.0]
# 242       17.82  1.75    Male     No   Sat  Dinner     2    (0.999, 2.0]
# 243       18.78  3.00  Female     No  Thur  Dinner     2  (2.476, 3.016]
#
#     bin_totalbill_eq_freq bin_tip_eq_int
# 0                       4       very low
# ...

# %% [markdown]
# ## Binning : Equal Interval
#
# ### pd.cut

# %%
df['bin_tip_eq_int']=pd.cut(df['tip'],5)
# df['bin_tip_eq_int']=pd.cut(df['tip'],5,labels=['very low','low','medium','high','very high'])
df
# Out:
#      total_bill   tip     sex smoker   day    time  size bin_tip_eq_freq  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2    (0.999, 2.0]
# 1         10.34  1.66    Male     No   Sun  Dinner     3    (0.999, 2.0]
# 2         21.01  3.50    Male     No   Sun  Dinner     3    (3.016, 4.0]
# 3         23.68  3.31    Male     No   Sun  Dinner     2    (3.016, 4.0]
# 4         24.59  3.61  Female     No   Sun  Dinner     4    (3.016, 4.0]
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     (4.0, 10.0]
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    (0.999, 2.0]
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    (0.999, 2.0]
# 242       17.82  1.75    Male     No   Sat  Dinner     2    (0.999, 2.0]
# 243       18.78  3.00  Female     No  Thur  Dinner     2  (2.476, 3.016]
#
#     bin_totalbill_eq_freq bin_tip_eq_int
# 0                       4   (0.991, 2.8]
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
#equal frequence
df['bin_tip_eq_freq'].value_counts().reset_index()
# Out:
#   bin_tip_eq_freq  count
# 0    (0.999, 2.0]     78
# 1    (3.016, 4.0]     57
# 2  (2.476, 3.016]     48
# 3     (4.0, 10.0]     41
# 4    (2.0, 2.476]     20

# %%
sns.countplot(x=df['bin_tip_eq_freq'])
# Out:
# <Axes: xlabel='bin_tip_eq_freq', ylabel='count'>

# %%
#equal interval
df['bin_tip_eq_int'].value_counts().reset_index()
# Out:
#   bin_tip_eq_int  count
# 0   (0.991, 2.8]    120
# 1     (2.8, 4.6]     93
# 2     (4.6, 6.4]     24
# 3     (6.4, 8.2]      5
# 4    (8.2, 10.0]      2

# %%
sns.countplot(x=df['bin_tip_eq_int'])
# Out:
# <Axes: xlabel='bin_tip_eq_int', ylabel='count'>

# %% [markdown]
# ## Bivariate Analysis
# tip vs total_bill

# %%
sns.heatmap(df[['size','tip','total_bill']].corr(method='spearman'),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,x='total_bill',y='tip')
sns.regplot(data=df,x='total_bill',y='tip',scatter=False, color='black',ci=None)
plt.title('Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')

# %%
df_agg=df.groupby('bin_totalbill_eq_freq')['tip'].mean().reset_index()
df_agg
# Out:
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/3899831303.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_agg=df.groupby('bin_totalbill_eq_freq')['tip'].mean().reset_index()
#   bin_totalbill_eq_freq       tip
# 0                     1  1.799677
# 1                     2  2.045667
# 2                     3  2.420323
# 3                     4  2.805333
# 4                     5  2.934000
# 5                     6  3.507097
# 6                     7  3.794333
# 7                     8  4.666452

# %%
sns.barplot(data=df_agg,x='bin_totalbill_eq_freq',y='tip')
plt.xlabel('bin_totalbill')
plt.ylabel('Average Tip')
plt.title('Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')

# %% [markdown]
# ## Soal 2 (2 poin)
#
# Buat analisis bivariat untuk melihat hubungan antara umur dengan survived (titanic seaborn), gunakan 5 bin (equal frequence)

# %%
df=sns.load_dataset('titanic')
df['age']=round(df['age'].fillna(df['age'].mean())).astype(int)
df['bin_age']=pd.qcut(df['age'],5)
df
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 0           0       3    male   22      1      0   7.2500        S   Third
# 1           1       1  female   38      1      0  71.2833        C   First
# 2           1       3  female   26      0      0   7.9250        S   Third
# 3           1       1  female   35      1      0  53.1000        S   First
# 4           0       3    male   35      0      0   8.0500        S   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 886         0       2    male   27      0      0  13.0000        S  Second
# 887         1       1  female   19      0      0  30.0000        S   First
# 888         0       3  female   30      1      2  23.4500        S   Third
# 889         1       1    male   26      0      0  30.0000        C   First
# 890         0       3    male   32      0      0   7.7500        Q   Third
#
# ...

# %%
df[df['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone, bin_age]
# Index: []

# %%
df_agg=df.groupby('bin_age')['survived'].mean().reset_index()
df_agg
# Out:
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/2797856495.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_agg=df.groupby('bin_age')['survived'].mean().reset_index()
#           bin_age  survived
# 0  (-0.001, 20.0]  0.455556
# 1    (20.0, 28.0]  0.358696
# 2    (28.0, 30.0]  0.312500
# 3    (30.0, 38.0]  0.460317
# 4    (38.0, 80.0]  0.372881

# %%
sns.barplot(data=df_agg,x='bin_age',y='survived')
plt.xlabel('bin_age')
plt.ylabel('Survived Rate')
plt.title('Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# `tip vs total_bill (sex)`

# %%
df=sns.load_dataset('tips')
df['bin_totalbill_eq_freq']=pd.qcut(df['total_bill'],5)
# df['bin_tip_eq_freq']=pd.qcut(df['tip'],5,labels=['very low','low','medium','high','very high'])
df
# Out:
#      total_bill   tip     sex smoker   day    time  size bin_totalbill_eq_freq
# 0         16.99  1.01  Female     No   Sun  Dinner     2      (16.222, 19.818]
# 1         10.34  1.66    Male     No   Sun  Dinner     3       (3.069, 12.636]
# 2         21.01  3.50    Male     No   Sun  Dinner     3      (19.818, 26.098]
# 3         23.68  3.31    Male     No   Sun  Dinner     2      (19.818, 26.098]
# 4         24.59  3.61  Female     No   Sun  Dinner     4      (19.818, 26.098]
# ..          ...   ...     ...    ...   ...     ...   ...                   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       (26.098, 50.81]
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       (26.098, 50.81]
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2      (19.818, 26.098]
# 242       17.82  1.75    Male     No   Sat  Dinner     2      (16.222, 19.818]
# 243       18.78  3.00  Female     No  Thur  Dinner     2      (16.222, 19.818]
#
# [244 rows x 8 columns]

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex')
sns.regplot(data=df[df['sex']=='Female'],x='total_bill',y='tip',scatter=False,ci=None)
sns.regplot(data=df[df['sex']=='Male'],x='total_bill',y='tip',scatter=False,ci=None)
plt.title('Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')

# %%
df_agg=df.groupby(['bin_totalbill_eq_freq','sex'])['tip'].mean().reset_index()
# Out:
# /var/folders/jt/r23kbqhx1q5ggqjrcs67nrvh0000gn/T/ipykernel_79649/1263688556.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_agg=df.groupby(['bin_totalbill_eq_freq','sex'])['tip'].mean().reset_index()

# %%
sns.barplot(data=df_agg,x='bin_totalbill_eq_freq',y='tip',hue='sex')
plt.xlabel('bin_totalbill')
plt.ylabel('Average Tip')
plt.xticks(rotation=45)
plt.title('Total Bill vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill vs Tip')

# %% [markdown]
# `tip vs total_bill (time)` pria

# %% [markdown]
# `tip vs total_bill (day)` wanita

# %%
df['weekday']=np.where(df['day'].isin(['Thur', 'Fri']),'weekdays','weekend')
